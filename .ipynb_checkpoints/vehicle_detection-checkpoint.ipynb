# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2
import glob
import time
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.preprocessing import StandardScaler
from skimage.feature import hog
# NOTE: the next import is only valid for scikit-learn version <= 0.17
# for scikit-learn >= 0.18 use:
from sklearn.model_selection import train_test_split
# from sklearn.cross_validation import train_test_split

# %%
def convert_color(img, conv='RGB2YCrCb'):
    if conv == 'RGB2YCrCb':
        return cv2.cvtColor(img, cv2.COLOR_RGB2YCrCb)
    if conv == 'BGR2YCrCb':
        return cv2.cvtColor(img, cv2.COLOR_BGR2YCrCb)
    if conv == 'LUV':
        return cv2.cvtColor(img, cv2.COLOR_RGB2LUV)
    if conv == 'HSV':
        return cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
    if color_space == 'HLS':
        return cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
    if color_space == 'YUV':
        return cv2.cvtColor(img, cv2.COLOR_RGB2YUV)
    if color_space == 'BGR':
        return cv2.cvtColor(img, cv2.COLOR_RGB2BGR)


# Extract features from a single image window
def single_img_features(img, color_space='RGB', spatial_size=(32, 32),
                        hist_bins=32, orient=9, 
                        pix_per_cell=8, cell_per_block=2, hog_channel=0,
                        spatial_feat=True, hist_feat=True, hog_feat=True):    
    #1) Define an empty list to receive features
    img_features = []
    #2) Apply color conversion if other than 'RGB'
    if color_space != 'RGB':
        if color_space == 'HSV':
            feature_image = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
        elif color_space == 'LUV':
            feature_image = cv2.cvtColor(img, cv2.COLOR_RGB2LUV)
        elif color_space == 'HLS':
            feature_image = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
        elif color_space == 'YUV':
            feature_image = cv2.cvtColor(img, cv2.COLOR_RGB2YUV)
        elif color_space == 'YCrCb':
            feature_image = cv2.cvtColor(img, cv2.COLOR_RGB2YCrCb)
    else: feature_image = np.copy(img)      
    #3) Compute spatial features if flag is set
    if spatial_feat == True:
        spatial_features = bin_spatial(feature_image, size=spatial_size)
        #4) Append features to list
        img_features.append(spatial_features)
    #5) Compute histogram features if flag is set
    if hist_feat == True:
        hist_features = color_hist(feature_image, nbins=hist_bins)
        #6) Append features to list
        img_features.append(hist_features)
    #7) Compute HOG features if flag is set
    if hog_feat == True:
        if hog_channel == 'ALL':
            hog_features = []
            for channel in range(feature_image.shape[2]):
                hog_features.extend(get_hog_features(feature_image[:,:,channel], 
                                    orient, pix_per_cell, cell_per_block, 
                                    vis=False, feature_vec=True))      
        else:
            hog_features = get_hog_features(feature_image[:,:,hog_channel], orient, 
                        pix_per_cell, cell_per_block, vis=False, feature_vec=True)
        #8) Append features to list
        img_features.append(hog_features)

    #9) Return concatenated array of features
    return np.concatenate(img_features)

# %%
# Define a function you will pass an image 
# and the list of windows to be searched (output of slide_windows())
def search_windows(img, windows, clf, scaler, color_space='RGB', 
                    spatial_size=(32, 32), hist_bins=32, 
                    hist_range=(0, 256), orient=9, 
                    pix_per_cell=8, cell_per_block=2, 
                    hog_channel=0, spatial_feat=True, 
                    hist_feat=True, hog_feat=True):

    #1) Create an empty list to receive positive detection windows
    on_windows = []
    #2) Iterate over all windows in the list
    for window in windows:
        #3) Extract the test window from original image
        test_img = cv2.resize(img[window[0][1]:window[1][1], window[0][0]:window[1][0]], (64, 64))      
        #4) Extract features for that window using single_img_features()
        features = single_img_features(test_img, color_space=color_space, 
                            spatial_size=spatial_size, hist_bins=hist_bins, 
                            orient=orient, pix_per_cell=pix_per_cell, 
                            cell_per_block=cell_per_block, 
                            hog_channel=hog_channel, spatial_feat=spatial_feat, 
                            hist_feat=hist_feat, hog_feat=hog_feat)
        #5) Scale extracted features to be fed to classifier
        test_features = scaler.transform(np.array(features).reshape(1, -1))
        #6) Predict using your classifier
        prediction = clf.predict(test_features)
        #7) If positive (prediction == 1) then save the window
        if prediction == 1:
            on_windows.append(window)
    #8) Return windows for positive detections
    return on_windows

# %%
# Read in cars and notcars
car_images ={}
car_images['far'] = glob.glob('vehicles/GTI_Far/*.png')
car_images['left'] = glob.glob('vehicles/GTI_Left/*.png')
car_images['middle_close'] = glob.glob('vehicles/GTI_MiddleClose/*.png')
car_images['right'] = glob.glob('vehicles/GTI_Right/*.png')
car_images['extracted'] = glob.glob('vehicles/KITTI_extracted/*.png')

not_car_images={}
not_car_images['gti'] = glob.glob('non-vehicles/GTI/*.png')
not_car_images['extra'] = glob.glob('non-vehicles/Extras/*.png')

train_cars = []
test_cars = []
train_not_cars = []
test_not_cars = []
split_percent = 0.8
for key,image_list in car_images.items():
    split = int(len(image_list)*split_percent)
    train_cars.extend(image_list[:split])
    test_cars.extend(image_list[split:])
for key,image_list in not_car_images.items():
    split = int(len(image_list)*split_percent)
    train_not_cars.extend(image_list[:split])
    test_not_cars.extend(image_list[split:])

print(' ---------------------------------------------')
print('|Train samples | cars: {} | not_cars: {}  |'.format(len(train_cars), len(train_not_cars)))
print('|---------------------------------------------|')
print('|Test samples  | cars: {} | not_cars: {}  |'.format(len(test_cars), len(test_not_cars)))
print(' ---------------------------------------------')
# Out:
#  ---------------------------------------------
# |Train samples | cars: 7032 | not_cars: 7174  |
# |---------------------------------------------|
# |Test samples  | cars: 1760 | not_cars: 1794  |
#  ---------------------------------------------

# %%
import matplotlib.image as mpimg
import numpy as np
import cv2
from skimage.feature import hog


# Define a function to return HOG features and visualization
def get_hog_features(img, orient, pix_per_cell, cell_per_block, 
                        vis=False, feature_vec=True):
    # Call with two outputs if vis==True
    if vis == True:
        features, hog_image = hog(img, orientations=orient, 
                                  pixels_per_cell=(pix_per_cell, pix_per_cell),
                                  cells_per_block=(cell_per_block, cell_per_block), 
                                  transform_sqrt=True, 
                                  visualise=vis, feature_vector=feature_vec)
        return features, hog_image
    # Otherwise call with one output
    else:      
        features = hog(img, orientations=orient, 
                       pixels_per_cell=(pix_per_cell, pix_per_cell),
                       cells_per_block=(cell_per_block, cell_per_block), 
                       transform_sqrt=True, 
                       visualise=vis, feature_vector=feature_vec)
        return features


def bin_spatial(img, size=(32, 32)):
    color1 = cv2.resize(img[:,:,0], size).ravel()
    color2 = cv2.resize(img[:,:,1], size).ravel()
    color3 = cv2.resize(img[:,:,2], size).ravel()
    return np.hstack((color1, color2, color3))
                        
def color_hist(img, nbins=32):    #bins_range=(0, 256)
    # Compute the histogram of the color channels separately
    channel1_hist = np.histogram(img[:,:,0], bins=nbins)
    channel2_hist = np.histogram(img[:,:,1], bins=nbins)
    channel3_hist = np.histogram(img[:,:,2], bins=nbins)
    # Concatenate the histograms into a single feature vector
    hist_features = np.concatenate((channel1_hist[0], channel2_hist[0], channel3_hist[0]))
    # Return the individual histograms, bin_centers and feature vector
    return hist_features

def extract_features(image, color_space='RGB', spatial_size=(32, 32),
                        hist_bins=32, orient=9, 
                        pix_per_cell=8, cell_per_block=2, hog_channel=0,
                        spatial_feat=True, hist_feat=True, hog_feat=True):
    file_features = []
    file_features_mirror = []
    
    if color_space != 'RGB':
        if color_space == 'HSV':
            feature_image = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
        elif color_space == 'LUV':
            feature_image = cv2.cvtColor(image, cv2.COLOR_RGB2LUV)
        elif color_space == 'HLS':
            feature_image = cv2.cvtColor(image, cv2.COLOR_RGB2HLS)
        elif color_space == 'YUV':
            feature_image = cv2.cvtColor(image, cv2.COLOR_RGB2YUV)
        elif color_space == 'YCrCb':
            feature_image = cv2.cvtColor(image, cv2.COLOR_RGB2YCrCb)
    else: feature_image = np.copy(image)      

    if spatial_feat == True:
        spatial_features = bin_spatial(feature_image, size=spatial_size)
        file_features.append(spatial_features)
    if hist_feat == True:
        # Apply color_hist()
        hist_features = color_hist(feature_image, nbins=hist_bins)
        file_features.append(hist_features)
    if hog_feat == True:
    # Call get_hog_features() with vis=False, feature_vec=True
        if hog_channel == 'ALL':
            hog_features = []
            for channel in range(feature_image.shape[2]):
                hog_features.append(get_hog_features(feature_image[:,:,channel], 
                                    orient, pix_per_cell, cell_per_block, 
                                    vis=False, feature_vec=True))
            hog_features = np.ravel(hog_features)        
        else:
            hog_features = get_hog_features(feature_image[:,:,hog_channel], orient, 
                        pix_per_cell, cell_per_block, vis=False, feature_vec=True)
        # Append the new feature vector to the features list
        file_features.append(hog_features)
    return file_features


# Define a function to extract features from a list of images
# Have this function call bin_spatial() and color_hist()
def process_features(imgs, color_space='RGB', spatial_size=(32, 32),
                        hist_bins=32, orient=9, 
                        pix_per_cell=8, cell_per_block=2, hog_channel=0,
                        spatial_feat=True, hist_feat=True, hog_feat=True, extra=False):
    # Create a list to append feature vectors to
    features = []
    # Iterate through the list of images
    for file in imgs:
        file_features = []
        file_features_mirror = []
        # Read in each one by one
        image = mpimg.imread(file)
        file_features = extract_features(image, color_space, spatial_size,
                        hist_bins, orient, 
                        pix_per_cell, cell_per_block, hog_channel,
                        spatial_feat, hist_feat, hog_feat)
        
        # apply color conversion if other than 'RGB'
        features.append(np.concatenate(file_features))
        
        if extra:
            flipped_image = np.fliplr(image)
            file_features_mirror = extract_features(flipped_image, color_space, spatial_size,
                            hist_bins, orient, 
                            pix_per_cell, cell_per_block, hog_channel,
                            spatial_feat, hist_feat, hog_feat)
            features.append(np.concatenate(file_features_mirror))
        
        
    # Return list of feature vectors
    return features
    


#stanrdize test & train sets
def gather_features(train_cars,test_cars,train_not_cars,test_not_cars):
    train_car_features = process_features(train_cars, color_space=color_space, 
                        spatial_size=spatial_size, hist_bins=hist_bins, 
                        orient=orient, pix_per_cell=pix_per_cell, 
                        cell_per_block=cell_per_block, 
                        hog_channel=hog_channel, spatial_feat=spatial_feat, 
                        hist_feat=hist_feat, hog_feat=hog_feat, extra=True)
    test_car_features = process_features(test_cars, color_space=color_space, 
                            spatial_size=spatial_size, hist_bins=hist_bins, 
                            orient=orient, pix_per_cell=pix_per_cell, 
                            cell_per_block=cell_per_block, 
                            hog_channel=hog_channel, spatial_feat=spatial_feat, 
                            hist_feat=hist_feat, hog_feat=hog_feat)
    train_notcar_features = process_features(train_not_cars, color_space=color_space, 
                            spatial_size=spatial_size, hist_bins=hist_bins, 
                            orient=orient, pix_per_cell=pix_per_cell, 
                            cell_per_block=cell_per_block, 
                            hog_channel=hog_channel, spatial_feat=spatial_feat, 
                            hist_feat=hist_feat, hog_feat=hog_feat,extra=True)
    test_notcar_features = process_features(test_not_cars, color_space=color_space, 
                            spatial_size=spatial_size, hist_bins=hist_bins, 
                            orient=orient, pix_per_cell=pix_per_cell, 
                            cell_per_block=cell_per_block, 
                            hog_channel=hog_channel, spatial_feat=spatial_feat, 
                            hist_feat=hist_feat, hog_feat=hog_feat)

    train_len = len(train_car_features)+len(train_notcar_features)
    # Standardizing all x
    X = np.vstack((train_car_features, train_notcar_features,test_car_features, test_notcar_features)).astype(np.float64)                        
    # Fit a per-column scaler
    x_scaler = StandardScaler().fit(X)
    # Apply the scaler to X
    x_all = x_scaler.transform(X)
    X_train = x_all[:train_len]
    X_test = x_all[train_len:]

    # Define the labels vector
    y_train = np.hstack((np.ones(len(train_car_features)), np.zeros(len(train_notcar_features))))
    y_test = np.hstack((np.ones(len(test_car_features)), np.zeros(len(test_notcar_features))))

    return X_train,X_test,y_train,y_test, x_scaler

# %%
img_size = mpimg.imread(train_cars[0]).shape
print('Image Size: ',img_size)

# Parameters 
color_space = 'YCrCb' # Can be RGB, HSV, LUV, HLS, YUV, YCrCb
orient = 9  # HOG orientations
pix_per_cell = 16 # HOG pixels per cell
cell_per_block = 1 # HOG cells per block
hog_channel = 'ALL' # Can be 0, 1, 2, or "ALL"
spatial_size = (32, 32) # Spatial binning dimensions
hist_bins = 32    # Number of histogram bins
spatial_feat = True # Spatial features on or off
hist_feat = True # Histogram features on or off
hog_feat = True # HOG features on or off
# y_start_stop = [None, None] # Min and max in y to search in slide_window()

X_train, X_test, y_train, y_test, X_scaler = gather_features(train_cars,test_cars,train_not_cars,test_not_cars)

print(' -----------------------------------------')
print('|Train set | X_train:{} y_train:{}  |'.format(len(X_train), len(y_train)))
print('|-----------------------------------------|')
print('|Test set  | X_test: {} y_test:{}     |'.format(len(X_test), len(y_test)))
print(' -----------------------------------------')


from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)
print('shuffled training data')
# Out:
# Image Size:  (64, 64, 3)
#  -----------------------------------------
# |Train set | X_train:28412 y_train:28412  |
# |-----------------------------------------|
# |Test set  | X_test: 3554 y_test:3554     |
#  -----------------------------------------
# shuffled training data

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV

print('Using:',orient,'orientations',pix_per_cell,
    'pixels per cell and', cell_per_block,'cells per block')
print('Feature vector length:', len(X_train[0]))
# Use a linear SVC 
# svc = LinearSVC(max_iter=10000, verbose=0)
# Check the training time for the SVC
t=time.time()
parameters = {'kernel':('linear', 'rbf'), 'C':[1, 10]}
# svm = LinearSVC()
# svc = CalibratedClassifierCV(svm) 
svc= svm.SVC(kernel='linear',probability=True)
# svc = GridSearchCV(svc, parameters,n_jobs=5, pre_dispatch=4)
# param_grid = { 'C':[1.0,10.0] }
# svc = GridSearchCV(svc,parameters, n_jobs=5, pre_dispatch=4)
svc.fit(X_train, y_train)

t2 = time.time()
print('Took {}(sec) to train SVC...'.format(round(t2-t, 2)))
# Check the score of the SVC
t=time.time()
acc = round(svc.score(X_test, y_test), 4)
t2 = time.time()
print('Test Accuracy of SVC = ',acc, ' Took {}(sec):'.format(round(t2-t, 2)) )
# print(svc.best_params_)
# Out:
# Using: 9 orientations 16 pixels per cell and 1 cells per block
# Feature vector length: 3600
# Took 614.72(sec) to train SVC...
# Test Accuracy of SVC =  0.9848  Took 9.77(sec):

# %%
#print(svc.best_params_)
#{'C': 10, 'kernel': 'rbf'}

def image_display(image,title=''):
#     fig = plt.figure(figsize=(10, 10))
    plt.title(title)
    plt.imshow(image, cmap='Greys_r')
    plt.show()

# %%
def find_cars(img, ystart, ystop, scale, svc, X_scaler, orient, pix_per_cell, cell_per_block, spatial_size, hist_bins,color_space):
    boxes= []
    predictions=[]
    
    draw_img = np.copy(img)
#     img = img.astype(np.float32)/255
    
    img_tosearch = img[ystart:ystop,:,:]
    if color_space != 'RGB':
        ctrans_tosearch = convert_color(img_tosearch, conv=color_space)
    else:
        ctrans_tosearch = np.copy(img_tosearch)
#     image_display(ctrans_tosearch,color_space)

    if scale != 1:
        imshape = ctrans_tosearch.shape
        ctrans_tosearch = cv2.resize(ctrans_tosearch, (np.int(imshape[1]/scale), np.int(imshape[0]/scale)))
    
    ch1 = ctrans_tosearch[:,:,0]
    ch2 = ctrans_tosearch[:,:,1]
    ch3 = ctrans_tosearch[:,:,2]
    
    # Define blocks and steps as above
    nxblocks = (ch1.shape[1] // pix_per_cell) - cell_per_block + 1
    nyblocks = (ch1.shape[0] // pix_per_cell) - cell_per_block + 1 
    nfeat_per_block = orient*cell_per_block**2
    
    # 64 was the orginal sampling rate, with 8 cells and 8 pix per cell
    window = 64
    nblocks_per_window = (window // pix_per_cell) - cell_per_block + 1
    cells_per_step = 2  # Instead of overlap, define how many cells to step
    nxsteps = (nxblocks - nblocks_per_window) // cells_per_step
    nysteps = (nyblocks - nblocks_per_window) // cells_per_step
    
    # Compute individual channel HOG features for the entire image
    hog1, im1 = get_hog_features(ch1, orient, pix_per_cell, cell_per_block,vis=True, feature_vec=False)
    hog2, im2 = get_hog_features(ch2, orient, pix_per_cell, cell_per_block,vis=True, feature_vec=False)
    hog3,im3 = get_hog_features(ch3, orient, pix_per_cell, cell_per_block,vis=True, feature_vec=False)

    for xb in range(nxsteps):
        for yb in range(nysteps):
            ypos = yb*cells_per_step
            xpos = xb*cells_per_step
            # Extract HOG for this patch
            hog_feat1 = hog1[ypos:ypos+nblocks_per_window, xpos:xpos+nblocks_per_window].ravel() 
            hog_feat2 = hog2[ypos:ypos+nblocks_per_window, xpos:xpos+nblocks_per_window].ravel() 
            hog_feat3 = hog3[ypos:ypos+nblocks_per_window, xpos:xpos+nblocks_per_window].ravel() 
            hog_features = np.hstack((hog_feat1, hog_feat2, hog_feat3))

            xleft = xpos*pix_per_cell
            ytop = ypos*pix_per_cell

            # Extract the image patch
            subimg = cv2.resize(ctrans_tosearch[ytop:ytop+window, xleft:xleft+window], (64,64))
            
            # Get color features
            spatial_features = bin_spatial(subimg, size=spatial_size)
            hist_features = color_hist(subimg, nbins=hist_bins)

            # Scale features and make a prediction
            test_features = X_scaler.transform(np.hstack((spatial_features, hist_features, hog_features)).reshape(1, -1))    
            #test_features = X_scaler.transform(np.hstack((shape_feat, hist_feat)).reshape(1, -1))    
            test_prediction = svc.predict(test_features)
            pred_score = svc.predict_proba(test_features)
            if test_prediction == 1 and pred_score[0][1]>0.8:
#                 predictions.append()
                xbox_left = np.int(xleft*scale)
                ytop_draw = np.int(ytop*scale)
                win_draw = np.int(window*scale)
                boxes.append(((xbox_left, ytop_draw+ystart),(xbox_left+win_draw,ytop_draw+win_draw+ystart)))
#                 cv2.rectangle(draw_img,(xbox_left, ytop_draw+ystart),(xbox_left+win_draw,ytop_draw+win_draw+ystart),(0,255,0),6) 
    return boxes,predictions

# %%
# Define a function to draw bounding boxes
def draw_boxes(img, bboxes, color=(0, 0, 255), thick=6):
    # Make a copy of the image
    imcopy = np.copy(img)
    # Iterate through the bounding boxes
    for bbox in bboxes:
        # Draw a rectangle given bbox coordinates
        cv2.rectangle(imcopy, bbox[0], bbox[1], color, thick)
    # Return the image copy with boxes drawn
    return imcopy

# %%
def adjust_gamma(image, gamma=1.0):
    ''' 
    build a lookup table mapping the pixel values [0, 255] to
    their adjusted gamma values
    '''
    invGamma = 1.0 / gamma
    table = np.array([((i / 255.0) ** invGamma) * 255 for i in np.arange(0, 256)]).astype("uint8")

    # apply gamma correction using the lookup table
    return cv2.LUT(image, table)

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import pickle
import cv2
from scipy.ndimage.measurements import label

class Vehicle():
    def __init__(self, center=None, bbox=None):
        self.center=center
        self.count_appeared = 0
        self.bbox = bbox
        
    def covers_range(self,new_point):
        offset = 50
        if self.center != None and \
            new_point[0] >= self.center[0]-offset and  new_point[0] <=self.center[0]+offset and \
            new_point[1] >= self.center[1]-offset and  new_point[1] <=self.center[1]+offset:
            return True
        return False
    
def add_heat(heatmap, bbox_list):
    # Iterate through list of bboxes
    for box in bbox_list:
        # Add += 1 for all pixels inside each bbox
        # Assuming each "box" takes the form ((x1, y1), (x2, y2))
        heatmap[box[0][1]:box[1][1], box[0][0]:box[1][0]] += 1

    # Return updated heatmap
    return heatmap# Iterate through list of bboxes
    
def apply_threshold(heatmap, threshold):
    # Zero out pixels below the threshold
#     print( heatmap[heatmap > 0] )
    heatmap[heatmap < threshold] = 0
    # Return thresholded map
    return heatmap

def draw_labeled_bboxes(img, labels, vehicles):
    centers={}
    good_vehicles=[]
    old_vehicles = list(vehicles)
            
    # Iterate through all detected cars
    new_additions = 0
    for car_number in range(1, labels[1]+1):
        # Find pixels with each car_number label value
        nonzero = (labels[0] == car_number).nonzero()
        # Identify x and y values of those pixels
        nonzeroy = np.array(nonzero[0])
        nonzerox = np.array(nonzero[1])
        # Define a bounding box based on min/max x and y
        bbox = ((np.min(nonzerox), np.min(nonzeroy)), (np.max(nonzerox), np.max(nonzeroy)))
        
        center = (np.mean([bbox[0][0], bbox[0][1]]), np.mean([bbox[1][0], bbox[1][1]]))
        centers[car_number]=center
        in_range = False
        
        if len(vehicles) >0:
            for vehicle in vehicles:
                if vehicle.covers_range(center):
                    vehicle.count_appeared +=1
                    print('counter',vehicle.count_appeared)
                    new_bbox=((np.min([bbox[0][0],vehicle.bbox[0][0]]), np.min([bbox[0][1], vehicle.bbox[0][1]])),\
                              (np.max([bbox[1][0],vehicle.bbox[1][0]]),np.max([bbox[1][1], vehicle.bbox[1][1]])))
                    vehicle.bbox= new_bbox
                    vehicle.center =(np.mean([new_bbox[0][0], new_bbox[0][1]]), np.mean([new_bbox[1][0], new_bbox[1][1]]))

                    in_range= True
                    break
        
        if in_range is False:
#             print('Adding new veicle', center)
            new_vehicle = Vehicle(center,bbox)
            vehicles.append(new_vehicle)
            new_additions+=1
        
    #filter bad vehicles except the 
    for i in range(len(vehicles)-new_additions):
        if vehicles[i].count_appeared >1 and old_vehicles[i].count_appeared < vehicles[i].count_appeared:
            good_vehicles.append(vehicles[i])
    good_vehicles.extend(vehicles[len(vehicles)-new_additions-1:])
    print('good',len(good_vehicles), '---original', len(vehicles), '---', new_additions)
    for vehicle in good_vehicles:
#         if vehicle.count_appeared>0 or len(good_vehicles)==new_additions:
            # Draw the box on the image
        cv2.rectangle(img, vehicle.bbox[0],vehicle.bbox[1], (255,0,0), 6)

    # Return the image
    return img, centers, good_vehicles

# %%
def pipeline(image):
    global vehicles
    draw_image = np.copy(image)
    heat = np.zeros_like(image[:,:,0]).astype(np.float)
    im = np.copy(image)
    # Uncomment the following line if you extracted training
    # data from .png images (scaled 0 to 1 by mpimg) and the
    # image you are searching is a .jpg (scaled 0 to 255)
    im = im.astype(np.float32)/255
                 
    ystart = 400
    ystop = 656
    scale = 1.5
    #'RGB2YCrCb' , 'BGR2YCrCb' , 'LUV', 'HSV', 'HLS', 'YUV':
    color_space = 'RGB2YCrCb'
    bboxes,predictions = find_cars(im, ystart, ystop, scale, svc, X_scaler, orient, pix_per_cell, cell_per_block, spatial_size, hist_bins, color_space)
    heat = add_heat(heat,bboxes)
    # Apply threshold to help remove false positives
    heat = apply_threshold(heat,1)
    
    # Visualize the heatmap when displaying    
    heatmap = np.clip(heat, 0, 255)
  
    # Find final boxes from heatmap using label function
    labels = label(heatmap)
#     draw_img = draw_boxes(np.copy(image), bboxes, color=(0, 0, 255), thick=6)
    print('length',labels[1], len(predictions), len(bboxes))
    
    draw_img,centers, vehicles = draw_labeled_bboxes(np.copy(image), labels, vehicles)
    i =0
    font = cv2.FONT_HERSHEY_SIMPLEX
    print('processed vehicels', len(vehicles))
    for vehicle in vehicles:
#         print(vehicle.center,vehicle.count_appeared)
        cv2.putText(draw_img,'{} : {}'.format(vehicle.center,vehicle.count_appeared),(850,50+i), font, 1,(255,255,255),2)
        i+=50
    
#     print(centers)
#     fig = plt.figure()
#     plt.subplot(121)
#     plt.imshow(draw_img)
#     plt.title('Car Positions')
#     plt.subplot(122)
#     plt.imshow(heatmap, cmap='hot')
#     plt.title('Heat Map')
#     fig.tight_layout()
#     plt.show()
    return draw_img
#     plt.imshow(out_img2)
#     plt.show()

# %%
vehicles = []
o1= pipeline(mpimg.imread('test_images/test3.jpg'))
image_display(o1,'test3')
o1=pipeline(mpimg.imread('test_images/test1.jpg'))
image_display(o1, 'test1')
# o1=pipeline(mpimg.imread('test_images/test2.jpg'))
# image_display(o1,'test2')
o1=pipeline(mpimg.imread('test_images/test4.jpg'))
image_display(o1,'test4')
o1=pipeline(mpimg.imread('test_images/test5.jpg'))
image_display(o1,'test5')
o1=pipeline(mpimg.imread('test_images/test6.jpg'))
image_display(o1,'test6')
print('done')
# Out:
# length 1 0 1
# good 1 ---original 1 --- 1
# processed vehicels 1
# length 2 0 3
# counter 1
# good 2 ---original 2 --- 1
# processed vehicels 2
# length 2 0 4
# counter 2
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
# length 1 0 2
# good 2 ---original 2 --- 1
# processed vehicels 2
# length 2 0 5
# counter 1
# counter 2
# good 1 ---original 2 --- 0
# processed vehicels 1
# done

# %%
image = mpimg.imread('vehicles/GTI_Far/image0000.png')
image_display(image)
flipped_image = np.fliplr(image)
image_display(flipped_image)

# %%
from moviepy.editor import VideoFileClip
from IPython.display import HTML
vehicles = []
video_output = 'project_output.mp4'
clip = VideoFileClip('project_video.mp4')
sub_clip = clip.subclip('00:00:35','00:00:45')
project_clip = sub_clip.fl_image(pipeline)
# %time project_clip.write_videofile(video_output, audio=False)
# Out:
# ----
# ----
# ----
# ----
# good 1 ---original 1 --- 1
# processed vehicels 1
# [MoviePy] >>>> Building video project_output.mp4
# [MoviePy] Writing video project_output.mp4
#   0%|          | 1/251 [00:00<03:02,  1.37it/s]
# ----
# ----
# ----
# ----
# counter 1
# good 1 ---original 1 --- 0
# processed vehicels 1
#   1%|          | 2/251 [00:01<02:58,  1.40it/s]
# ----
# ----
# ----
# counter 2
# good 1 ---original 1 --- 0
# processed vehicels 1
#   1%|          | 3/251 [00:02<02:54,  1.42it/s]
# ----
# ----
# ----
# counter 3
# good 1 ---original 1 --- 0
# processed vehicels 1
#   2%|▏         | 4/251 [00:02<02:55,  1.41it/s]
# ----
# ----
# ----
# counter 4
# good 1 ---original 1 --- 0
# processed vehicels 1
#   2%|▏         | 5/251 [00:03<02:50,  1.44it/s]
# ----
# ----
# ----
# counter 5
# good 1 ---original 1 --- 0
# processed vehicels 1
#   2%|▏         | 6/251 [00:04<02:47,  1.46it/s]
# ----
# ----
# ----
# counter 6
# good 1 ---original 1 --- 0
# processed vehicels 1
#   3%|▎         | 7/251 [00:04<02:50,  1.44it/s]
# ----
# ----
# ----
# ----
# counter 7
# good 1 ---original 1 --- 0
# processed vehicels 1
#   3%|▎         | 8/251 [00:05<02:50,  1.42it/s]
# ----
# ----
# ----
# counter 8
# good 1 ---original 1 --- 0
# processed vehicels 1
#   4%|▎         | 9/251 [00:06<02:56,  1.37it/s]
# ----
# ----
# ----
# counter 9
# good 1 ---original 1 --- 0
# processed vehicels 1
#   4%|▍         | 10/251 [00:07<02:55,  1.37it/s]
# ----
# ----
# ----
# counter 10
# good 1 ---original 1 --- 0
# processed vehicels 1
#   4%|▍         | 11/251 [00:07<03:00,  1.33it/s]
# ----
# ----
# ----
# counter 11
# good 1 ---original 1 --- 0
# processed vehicels 1
#   5%|▍         | 12/251 [00:08<03:00,  1.32it/s]
# ----
# ----
# ----
# counter 12
# good 1 ---original 1 --- 0
# processed vehicels 1
#   5%|▌         | 13/251 [00:09<02:59,  1.32it/s]
# ----
# ----
# ----
# counter 13
# good 1 ---original 1 --- 0
# processed vehicels 1
#   6%|▌         | 14/251 [00:10<03:00,  1.32it/s]
# ----
# ----
# ----
# counter 14
# good 1 ---original 1 --- 0
# processed vehicels 1
#   6%|▌         | 15/251 [00:10<02:57,  1.33it/s]
# ----
# ----
# ----
# counter 15
# good 1 ---original 1 --- 0
# processed vehicels 1
#   6%|▋         | 16/251 [00:11<02:54,  1.35it/s]
# ----
# ----
# ----
# ----
# ----
# counter 16
# good 1 ---original 1 --- 0
# processed vehicels 1
#   7%|▋         | 17/251 [00:12<02:50,  1.37it/s]
# ----
# ----
# ----
# ----
# counter 17
# good 1 ---original 1 --- 0
# processed vehicels 1
#   7%|▋         | 18/251 [00:13<02:48,  1.38it/s]
# ----
# ----
# ----
# ----
# counter 18
# good 1 ---original 1 --- 0
# processed vehicels 1
#   8%|▊         | 19/251 [00:13<02:45,  1.40it/s]
# ----
# ----
# ----
# ----
# counter 19
# good 1 ---original 1 --- 0
# processed vehicels 1
#   8%|▊         | 20/251 [00:14<02:42,  1.42it/s]
# ----
# ----
# ----
# ----
# counter 20
# good 1 ---original 1 --- 0
# processed vehicels 1
#   8%|▊         | 21/251 [00:15<02:49,  1.36it/s]
# ----
# ----
# ----
# ----
# ----
# counter 21
# good 1 ---original 1 --- 0
# processed vehicels 1
#   9%|▉         | 22/251 [00:16<02:52,  1.32it/s]
# ----
# ----
# ----
# ----
# ----
# counter 22
# good 1 ---original 1 --- 0
# processed vehicels 1
#   9%|▉         | 23/251 [00:16<02:49,  1.34it/s]
# ----
# ----
# ----
# ----
# counter 23
# good 1 ---original 1 --- 0
# processed vehicels 1
#  10%|▉         | 24/251 [00:17<02:45,  1.37it/s]
# ----
# ----
# ----
# ----
# counter 24
# good 1 ---original 1 --- 0
# processed vehicels 1
#  10%|▉         | 25/251 [00:18<02:43,  1.38it/s]
# ----
# ----
# ----
# ----
# counter 25
# good 1 ---original 1 --- 0
# processed vehicels 1
#  10%|█         | 26/251 [00:18<02:43,  1.38it/s]
# ----
# ----
# ----
# ----
# counter 26
# good 1 ---original 1 --- 0
# processed vehicels 1
#  11%|█         | 27/251 [00:19<02:39,  1.40it/s]
# ----
# ----
# ----
# ----
# counter 27
# good 1 ---original 1 --- 0
# processed vehicels 1
#  11%|█         | 28/251 [00:20<02:49,  1.32it/s]
# ----
# ----
# ----
# ----
# counter 28
# good 1 ---original 1 --- 0
# processed vehicels 1
#  12%|█▏        | 29/251 [00:21<02:48,  1.32it/s]
# ----
# ----
# ----
# ----
# counter 29
# good 1 ---original 1 --- 0
# processed vehicels 1
#  12%|█▏        | 30/251 [00:22<02:58,  1.24it/s]
# ----
# ----
# ----
# ----
# counter 30
# good 1 ---original 1 --- 0
# processed vehicels 1
#  12%|█▏        | 31/251 [00:22<02:50,  1.29it/s]
# ----
# ----
# ----
# ----
# counter 31
# good 1 ---original 1 --- 0
# processed vehicels 1
#  13%|█▎        | 32/251 [00:23<02:42,  1.35it/s]
# ----
# ----
# ----
# ----
# counter 32
# good 1 ---original 1 --- 0
# processed vehicels 1
#  13%|█▎        | 33/251 [00:24<02:36,  1.39it/s]
# ----
# ----
# ----
# ----
# counter 33
# good 1 ---original 1 --- 0
# processed vehicels 1
#  14%|█▎        | 34/251 [00:24<02:31,  1.43it/s]
# ----
# ----
# ----
# ----
# counter 34
# good 1 ---original 1 --- 0
# processed vehicels 1
#  14%|█▍        | 35/251 [00:25<02:31,  1.43it/s]
# ----
# ----
# ----
# ----
# counter 35
# good 1 ---original 1 --- 0
# processed vehicels 1
#  14%|█▍        | 36/251 [00:26<02:34,  1.39it/s]
# ----
# ----
# ----
# ----
# counter 36
# good 1 ---original 1 --- 0
# processed vehicels 1
#  15%|█▍        | 37/251 [00:26<02:29,  1.43it/s]
# ----
# ----
# ----
# ----
# counter 37
# good 1 ---original 1 --- 0
# processed vehicels 1
#  15%|█▌        | 38/251 [00:27<02:39,  1.34it/s]
# ----
# ----
# ----
# ----
# counter 38
# good 1 ---original 1 --- 0
# processed vehicels 1
#  16%|█▌        | 39/251 [00:28<02:45,  1.28it/s]
# ----
# ----
# ----
# ----
# counter 39
# good 1 ---original 1 --- 0
# processed vehicels 1
#  16%|█▌        | 40/251 [00:29<02:41,  1.31it/s]
# ----
# ----
# ----
# ----
# counter 40
# good 1 ---original 1 --- 0
# processed vehicels 1
#  16%|█▋        | 41/251 [00:30<02:33,  1.36it/s]
# ----
# ----
# ----
# ----
# counter 41
# good 1 ---original 1 --- 0
# processed vehicels 1
#  17%|█▋        | 42/251 [00:30<02:28,  1.41it/s]
# ----
# ----
# ----
# ----
# counter 42
# good 1 ---original 1 --- 0
# processed vehicels 1
#  17%|█▋        | 43/251 [00:31<02:26,  1.42it/s]
# ----
# ----
# ----
# ----
# counter 43
# good 1 ---original 1 --- 0
# processed vehicels 1
#  18%|█▊        | 44/251 [00:32<02:24,  1.43it/s]
# ----
# ----
# ----
# ----
# counter 44
# good 1 ---original 1 --- 0
# processed vehicels 1
#  18%|█▊        | 45/251 [00:32<02:24,  1.42it/s]
# ----
# ----
# ----
# ----
# counter 45
# good 1 ---original 1 --- 0
# processed vehicels 1
#  18%|█▊        | 46/251 [00:33<02:25,  1.41it/s]
# ----
# ----
# ----
# ----
# counter 46
# good 1 ---original 1 --- 0
# processed vehicels 1
#  19%|█▊        | 47/251 [00:34<02:43,  1.25it/s]
# ----
# ----
# ----
# ----
# counter 47
# good 1 ---original 1 --- 0
# processed vehicels 1
#  19%|█▉        | 48/251 [00:35<02:34,  1.31it/s]
# ----
# ----
# ----
# ----
# counter 48
# good 1 ---original 1 --- 0
# processed vehicels 1
#  20%|█▉        | 49/251 [00:35<02:31,  1.33it/s]
# ----
# ----
# ----
# ----
# counter 49
# good 1 ---original 1 --- 0
# processed vehicels 1
#  20%|█▉        | 50/251 [00:36<02:30,  1.34it/s]
# ----
# ----
# ----
# ----
# counter 50
# good 1 ---original 1 --- 0
# processed vehicels 1
#  20%|██        | 51/251 [00:37<02:33,  1.30it/s]
# ----
# ----
# ----
# ----
# counter 51
# good 1 ---original 1 --- 0
# processed vehicels 1
#  21%|██        | 52/251 [00:38<02:26,  1.36it/s]
# ----
# ----
# ----
# ----
# counter 52
# good 1 ---original 1 --- 0
# processed vehicels 1
#  21%|██        | 53/251 [00:38<02:29,  1.32it/s]
# ----
# ----
# ----
# ----
# ----
# counter 53
# good 1 ---original 1 --- 0
# processed vehicels 1
#  22%|██▏       | 54/251 [00:39<02:24,  1.36it/s]
# ----
# ----
# ----
# ----
# ----
# counter 54
# good 1 ---original 1 --- 0
# processed vehicels 1
#  22%|██▏       | 55/251 [00:40<02:20,  1.39it/s]
# ----
# ----
# ----
# ----
# ----
# counter 55
# good 1 ---original 1 --- 0
# processed vehicels 1
#  22%|██▏       | 56/251 [00:41<02:25,  1.34it/s]
# ----
# ----
# ----
# ----
# ----
# ----
# counter 56
# good 1 ---original 1 --- 0
# processed vehicels 1
#  23%|██▎       | 57/251 [00:41<02:25,  1.34it/s]
# ----
# ----
# ----
# ----
# ----
# counter 57
# good 1 ---original 1 --- 0
# processed vehicels 1
#  23%|██▎       | 58/251 [00:42<02:23,  1.35it/s]
# ----
# ----
# ----
# ----
# ----
# counter 58
# good 1 ---original 1 --- 0
# processed vehicels 1
# ----
# ----
# ----
# ----
# ----
#  24%|██▎       | 59/251 [00:43<02:29,  1.29it/s]
# counter 59
# good 1 ---original 1 --- 0
# processed vehicels 1
#  24%|██▍       | 60/251 [00:44<02:39,  1.19it/s]
# ----
# ----
# ----
# ----
# ----
# counter 60
# good 1 ---original 1 --- 0
# processed vehicels 1
#  24%|██▍       | 61/251 [00:45<02:43,  1.16it/s]
# ----
# ----
# ----
# ----
# ----
# counter 61
# good 1 ---original 1 --- 0
# processed vehicels 1
#  25%|██▍       | 62/251 [00:46<02:43,  1.15it/s]
# ----
# ----
# ----
# ----
# ----
# counter 62
# good 1 ---original 1 --- 0
# processed vehicels 1
#  25%|██▌       | 63/251 [00:47<02:44,  1.14it/s]
# ----
# ----
# ----
# ----
# good 3 ---original 3 --- 2
# processed vehicels 3
#  25%|██▌       | 64/251 [00:47<02:35,  1.20it/s]
# ----
# ----
# ----
# ----
# counter 1
# counter 1
# good 1 ---original 3 --- 0
# processed vehicels 1
#  26%|██▌       | 65/251 [00:48<02:32,  1.22it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  26%|██▋       | 66/251 [00:49<02:28,  1.25it/s]
# ----
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
#  27%|██▋       | 67/251 [00:50<02:23,  1.29it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  27%|██▋       | 68/251 [00:50<02:17,  1.33it/s]
# ----
# ----
# ----
# ----
# counter 3
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  27%|██▋       | 69/251 [00:51<02:13,  1.36it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  28%|██▊       | 70/251 [00:52<02:11,  1.37it/s]
# ----
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
#  28%|██▊       | 71/251 [00:53<02:16,  1.32it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  29%|██▊       | 72/251 [00:53<02:23,  1.25it/s]
# ----
# ----
# ----
# ----
# counter 3
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  29%|██▉       | 73/251 [00:54<02:26,  1.21it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  29%|██▉       | 74/251 [00:55<02:27,  1.20it/s]
# ----
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
#  30%|██▉       | 75/251 [00:56<02:27,  1.19it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  30%|███       | 76/251 [00:57<02:30,  1.17it/s]
# ----
# ----
# ----
# ----
# counter 3
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  31%|███       | 77/251 [00:58<02:25,  1.19it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  31%|███       | 78/251 [00:59<02:24,  1.19it/s]
# ----
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
#  31%|███▏      | 79/251 [00:59<02:27,  1.16it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  32%|███▏      | 80/251 [01:00<02:28,  1.15it/s]
# ----
# ----
# ----
# ----
# counter 3
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  32%|███▏      | 81/251 [01:01<02:27,  1.15it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  33%|███▎      | 82/251 [01:02<02:27,  1.15it/s]
# ----
# ----
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
#  33%|███▎      | 83/251 [01:03<02:25,  1.15it/s]
# ----
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  33%|███▎      | 84/251 [01:04<02:22,  1.17it/s]
# ----
# ----
# ----
# ----
# ----
# counter 3
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  34%|███▍      | 85/251 [01:05<02:21,  1.17it/s]
# ----
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  34%|███▍      | 86/251 [01:05<02:17,  1.20it/s]
# ----
# ----
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
#  35%|███▍      | 87/251 [01:06<02:12,  1.24it/s]
# ----
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  35%|███▌      | 88/251 [01:07<02:10,  1.25it/s]
# ----
# ----
# ----
# ----
# ----
# counter 3
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  35%|███▌      | 89/251 [01:08<02:06,  1.28it/s]
# ----
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  36%|███▌      | 90/251 [01:08<02:03,  1.30it/s]
# ----
# ----
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
#  36%|███▋      | 91/251 [01:09<02:01,  1.32it/s]
# ----
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  37%|███▋      | 92/251 [01:10<01:59,  1.33it/s]
# ----
# ----
# ----
# ----
# ----
# counter 3
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  37%|███▋      | 93/251 [01:11<01:57,  1.34it/s]
# ----
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  37%|███▋      | 94/251 [01:11<01:58,  1.33it/s]
# ----
# ----
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
#  38%|███▊      | 95/251 [01:12<01:57,  1.33it/s]
# ----
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  38%|███▊      | 96/251 [01:13<01:54,  1.36it/s]
# ----
# ----
# ----
# ----
# ----
# counter 3
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  39%|███▊      | 97/251 [01:14<01:51,  1.38it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  39%|███▉      | 98/251 [01:14<01:49,  1.39it/s]
# ----
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
# ----
# ----
# ----
#  39%|███▉      | 99/251 [01:15<01:48,  1.41it/s]
# ----
# ----
# ----
# counter 2
# good 3 ---original 3 --- 2
# processed vehicels 3
# ----
# ----
#  40%|███▉      | 100/251 [01:16<01:47,  1.40it/s]
# ----
# ----
# ----
# ----
# counter 1
# counter 3
# counter 1
# good 1 ---original 3 --- 0
# processed vehicels 1
#  40%|████      | 101/251 [01:16<01:46,  1.42it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  41%|████      | 102/251 [01:17<01:44,  1.42it/s]
# ----
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
#  41%|████      | 103/251 [01:18<01:45,  1.40it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  41%|████▏     | 104/251 [01:18<01:44,  1.41it/s]
# ----
# ----
# ----
# ----
# counter 3
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  42%|████▏     | 105/251 [01:19<01:42,  1.42it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  42%|████▏     | 106/251 [01:20<01:42,  1.42it/s]
# ----
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
#  43%|████▎     | 107/251 [01:21<01:41,  1.42it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  43%|████▎     | 108/251 [01:21<01:41,  1.41it/s]
# ----
# ----
# ----
# ----
# counter 3
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  43%|████▎     | 109/251 [01:22<01:41,  1.39it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  44%|████▍     | 110/251 [01:23<01:46,  1.33it/s]
# ----
# ----
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
#  44%|████▍     | 111/251 [01:24<01:51,  1.26it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
# ----
# ----
# ----
#  45%|████▍     | 112/251 [01:25<01:57,  1.18it/s]
# ----
# ----
# counter 3
# counter 1
# good 2 ---original 3 --- 1
# processed vehicels 2
#  45%|████▌     | 113/251 [01:26<02:02,  1.13it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 3 --- 1
# processed vehicels 2
#  45%|████▌     | 114/251 [01:27<02:09,  1.06it/s]
# ----
# ----
# ----
# ----
# counter 1
# good 2 ---original 3 --- 1
# processed vehicels 2
#  46%|████▌     | 115/251 [01:28<02:13,  1.02it/s]
# ----
# ----
# ----
# ----
# counter 2
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  46%|████▌     | 116/251 [01:29<02:25,  1.08s/it]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  47%|████▋     | 117/251 [01:30<02:23,  1.07s/it]
# ----
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
#  47%|████▋     | 118/251 [01:31<02:26,  1.10s/it]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  47%|████▋     | 119/251 [01:33<02:27,  1.12s/it]
# ----
# ----
# ----
# ----
# counter 3
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  48%|████▊     | 120/251 [01:34<02:22,  1.09s/it]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  48%|████▊     | 121/251 [01:35<02:17,  1.06s/it]
# ----
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
#  49%|████▊     | 122/251 [01:36<02:11,  1.02s/it]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  49%|████▉     | 123/251 [01:36<02:04,  1.03it/s]
# ----
# ----
# ----
# ----
# counter 3
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  49%|████▉     | 124/251 [01:37<01:58,  1.07it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  50%|████▉     | 125/251 [01:38<01:53,  1.11it/s]
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
#  50%|█████     | 126/251 [01:39<01:48,  1.15it/s]
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  51%|█████     | 127/251 [01:40<01:43,  1.19it/s]
# ----
# ----
# ----
# ----
# counter 3
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  51%|█████     | 128/251 [01:40<01:40,  1.23it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  51%|█████▏    | 129/251 [01:41<01:37,  1.25it/s]
# ----
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
#  52%|█████▏    | 130/251 [01:42<01:34,  1.28it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  52%|█████▏    | 131/251 [01:43<01:33,  1.29it/s]
# ----
# ----
# ----
# ----
# counter 3
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  53%|█████▎    | 132/251 [01:43<01:32,  1.29it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  53%|█████▎    | 133/251 [01:44<01:30,  1.30it/s]
# ----
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
#  53%|█████▎    | 134/251 [01:45<01:29,  1.31it/s]
# ----
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  54%|█████▍    | 135/251 [01:46<01:28,  1.31it/s]
# ----
# ----
# ----
# counter 3
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  54%|█████▍    | 136/251 [01:46<01:27,  1.32it/s]
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  55%|█████▍    | 137/251 [01:47<01:26,  1.32it/s]
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
# ----
# ----
# ----
#  55%|█████▍    | 138/251 [01:48<01:25,  1.32it/s]
# ----
# counter 2
# good 3 ---original 3 --- 2
# processed vehicels 3
#  55%|█████▌    | 139/251 [01:49<01:24,  1.33it/s]
# ----
# ----
# counter 3
# good 1 ---original 3 --- 0
# processed vehicels 1
#  56%|█████▌    | 140/251 [01:49<01:24,  1.31it/s]
# ----
# ----
# good 2 ---original 2 --- 1
# processed vehicels 2
#  56%|█████▌    | 141/251 [01:50<01:23,  1.32it/s]
# ----
# ----
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  57%|█████▋    | 142/251 [01:51<01:22,  1.33it/s]
# ----
# ----
# counter 2
# good 1 ---original 1 --- 0
# processed vehicels 1
#  57%|█████▋    | 143/251 [01:52<01:21,  1.33it/s]
# ----
# ----
# ----
# counter 3
# good 2 ---original 2 --- 1
# processed vehicels 2
#  57%|█████▋    | 144/251 [01:52<01:21,  1.32it/s]
# ----
# ----
# ----
# counter 4
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  58%|█████▊    | 145/251 [01:53<01:20,  1.32it/s]
# ----
# ----
# good 2 ---original 2 --- 1
# processed vehicels 2
#  58%|█████▊    | 146/251 [01:54<01:19,  1.32it/s]
# ----
# ----
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  59%|█████▊    | 147/251 [01:55<01:19,  1.32it/s]
# ----
# ----
# counter 2
# good 1 ---original 1 --- 0
# processed vehicels 1
#  59%|█████▉    | 148/251 [01:56<01:19,  1.30it/s]
# ----
# ----
# counter 3
# good 1 ---original 1 --- 0
# processed vehicels 1
#  59%|█████▉    | 149/251 [01:56<01:18,  1.30it/s]
# ----
# ----
# counter 4
# good 1 ---original 1 --- 0
# processed vehicels 1
#  60%|█████▉    | 150/251 [01:57<01:17,  1.30it/s]
# ----
# ----
# counter 5
# good 1 ---original 1 --- 0
# processed vehicels 1
#  60%|██████    | 151/251 [01:58<01:17,  1.29it/s]
# ----
# ----
# counter 6
# good 1 ---original 1 --- 0
# processed vehicels 1
#  61%|██████    | 152/251 [01:59<01:17,  1.28it/s]
# ----
# ----
# counter 7
# good 1 ---original 1 --- 0
# processed vehicels 1
#  61%|██████    | 153/251 [02:00<01:20,  1.21it/s]
# ----
# ----
# counter 8
# good 1 ---original 1 --- 0
# processed vehicels 1
#  61%|██████▏   | 154/251 [02:01<01:28,  1.09it/s]
# ----
# ----
# counter 9
# good 1 ---original 1 --- 0
# processed vehicels 1
#  62%|██████▏   | 155/251 [02:02<01:34,  1.02it/s]
# ----
# ----
# counter 10
# good 1 ---original 1 --- 0
# processed vehicels 1
#  62%|██████▏   | 156/251 [02:03<01:39,  1.05s/it]
# ----
# ----
# counter 11
# good 1 ---original 1 --- 0
# processed vehicels 1
#  63%|██████▎   | 157/251 [02:04<01:44,  1.11s/it]
# ----
# ----
# counter 12
# good 1 ---original 1 --- 0
# processed vehicels 1
#  63%|██████▎   | 158/251 [02:06<01:49,  1.18s/it]
# ----
# ----
# counter 13
# good 1 ---original 1 --- 0
# processed vehicels 1
#  63%|██████▎   | 159/251 [02:07<01:49,  1.19s/it]
# ----
# ----
# ----
# counter 14
# good 2 ---original 2 --- 1
# processed vehicels 2
#  64%|██████▎   | 160/251 [02:08<01:48,  1.20s/it]
# ----
# ----
# ----
# counter 15
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  64%|██████▍   | 161/251 [02:09<01:48,  1.21s/it]
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
#  65%|██████▍   | 162/251 [02:10<01:44,  1.17s/it]
# ----
# ----
# ----
# counter 1
# counter 3
# good 1 ---original 2 --- 0
# processed vehicels 1
#  65%|██████▍   | 163/251 [02:12<01:42,  1.16s/it]
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
# ----
#  65%|██████▌   | 164/251 [02:13<01:41,  1.16s/it]
# ----
# ----
# ----
# counter 3
# counter 1
# good 2 ---original 3 --- 1
# processed vehicels 2
# ----
#  66%|██████▌   | 165/251 [02:14<01:46,  1.24s/it]
# ----
# ----
# ----
# counter 1
# counter 2
# good 2 ---original 3 --- 1
# processed vehicels 2
# ----
# ----
# ----
# counter 1
#  66%|██████▌   | 166/251 [02:16<01:49,  1.29s/it]
# good 2 ---original 3 --- 1
# processed vehicels 2
#  67%|██████▋   | 167/251 [02:17<01:53,  1.36s/it]
# ----
# ----
# ----
# counter 2
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
# ----
#  67%|██████▋   | 168/251 [02:18<01:49,  1.32s/it]
# ----
# ----
# ----
# counter 2
# good 3 ---original 3 --- 2
# processed vehicels 3
# ----
#  67%|██████▋   | 169/251 [02:19<01:45,  1.28s/it]
# ----
# ----
# ----
# counter 1
# counter 1
# counter 3
# good 1 ---original 3 --- 0
# processed vehicels 1
#  68%|██████▊   | 170/251 [02:21<01:38,  1.22s/it]
# ----
# ----
# ----
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
# ----
#  68%|██████▊   | 171/251 [02:22<01:36,  1.20s/it]
# ----
# ----
# counter 3
# good 2 ---original 3 --- 1
# processed vehicels 2
#  69%|██████▊   | 172/251 [02:23<01:31,  1.15s/it]
# ----
# ----
# ----
# counter 1
# good 2 ---original 3 --- 1
# processed vehicels 2
# ----
#  69%|██████▉   | 173/251 [02:24<01:28,  1.14s/it]
# ----
# ----
# ----
# counter 1
# counter 1
# good 2 ---original 3 --- 1
# processed vehicels 2
# ----
#  69%|██████▉   | 174/251 [02:25<01:28,  1.14s/it]
# ----
# ----
# ----
# counter 2
# counter 1
# good 2 ---original 3 --- 1
# processed vehicels 2
# ----
#  70%|██████▉   | 175/251 [02:26<01:26,  1.14s/it]
# ----
# ----
# ----
# counter 1
# counter 2
# good 2 ---original 3 --- 1
# processed vehicels 2
#  70%|███████   | 176/251 [02:27<01:26,  1.16s/it]
# ----
# ----
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  71%|███████   | 177/251 [02:28<01:25,  1.15s/it]
# ----
# ----
# counter 2
# good 1 ---original 1 --- 0
# processed vehicels 1
#  71%|███████   | 178/251 [02:30<01:22,  1.12s/it]
# ----
# ----
# ----
# counter 3
# good 2 ---original 2 --- 1
# processed vehicels 2
#  71%|███████▏  | 179/251 [02:31<01:20,  1.11s/it]
# ----
# ----
# counter 4
# good 1 ---original 2 --- 0
# processed vehicels 1
#  72%|███████▏  | 180/251 [02:32<01:22,  1.16s/it]
# ----
# ----
# good 2 ---original 2 --- 1
# processed vehicels 2
#  72%|███████▏  | 181/251 [02:33<01:27,  1.25s/it]
# ----
# ----
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
#  73%|███████▎  | 182/251 [02:35<01:24,  1.23s/it]
# ----
# ----
# counter 2
# good 1 ---original 1 --- 0
# processed vehicels 1
#  73%|███████▎  | 183/251 [02:36<01:21,  1.20s/it]
# ----
# ----
# counter 3
# good 1 ---original 1 --- 0
# processed vehicels 1
#  73%|███████▎  | 184/251 [02:37<01:18,  1.17s/it]
# ----
# ----
# counter 4
# good 1 ---original 1 --- 0
# processed vehicels 1
#  74%|███████▎  | 185/251 [02:38<01:18,  1.18s/it]
# ----
# ----
# counter 5
# good 1 ---original 1 --- 0
# processed vehicels 1
#  74%|███████▍  | 186/251 [02:39<01:15,  1.16s/it]
# ----
# ----
# counter 6
# good 1 ---original 1 --- 0
# processed vehicels 1
#  75%|███████▍  | 187/251 [02:40<01:13,  1.15s/it]
# ----
# ----
# counter 7
# good 1 ---original 1 --- 0
# processed vehicels 1
#  75%|███████▍  | 188/251 [02:41<01:11,  1.14s/it]
# ----
# ----
# counter 8
# good 1 ---original 1 --- 0
# processed vehicels 1
#  75%|███████▌  | 189/251 [02:43<01:15,  1.22s/it]
# ----
# ----
# counter 9
# good 1 ---original 1 --- 0
# processed vehicels 1
#  76%|███████▌  | 190/251 [02:44<01:12,  1.19s/it]
# ----
# ----
# counter 10
# good 1 ---original 1 --- 0
# processed vehicels 1
#  76%|███████▌  | 191/251 [02:45<01:11,  1.20s/it]
# ----
# ----
# counter 11
# good 1 ---original 1 --- 0
# processed vehicels 1
#  76%|███████▋  | 192/251 [02:46<01:12,  1.22s/it]
# ----
# ----
# counter 12
# good 1 ---original 1 --- 0
# processed vehicels 1
#  77%|███████▋  | 193/251 [02:47<01:09,  1.20s/it]
# ----
# ----
# counter 13
# good 1 ---original 1 --- 0
# processed vehicels 1
#  77%|███████▋  | 194/251 [02:49<01:07,  1.19s/it]
# ----
# ----
# counter 14
# good 1 ---original 1 --- 0
# processed vehicels 1
#  78%|███████▊  | 195/251 [02:50<01:06,  1.19s/it]
# ----
# ----
# counter 15
# good 1 ---original 1 --- 0
# processed vehicels 1
#  78%|███████▊  | 196/251 [02:51<01:05,  1.19s/it]
# ----
# ----
# counter 16
# good 1 ---original 1 --- 0
# processed vehicels 1
#  78%|███████▊  | 197/251 [02:52<01:03,  1.18s/it]
# ----
# ----
# counter 17
# good 1 ---original 1 --- 0
# processed vehicels 1
#  79%|███████▉  | 198/251 [02:53<01:02,  1.17s/it]
# ----
# ----
# counter 18
# good 1 ---original 1 --- 0
# processed vehicels 1
#  79%|███████▉  | 199/251 [02:55<01:02,  1.20s/it]
# ----
# ----
# counter 19
# good 1 ---original 1 --- 0
# processed vehicels 1
#  80%|███████▉  | 200/251 [02:56<01:00,  1.19s/it]
# ----
# ----
# counter 20
# good 1 ---original 1 --- 0
# processed vehicels 1
#  80%|████████  | 201/251 [02:57<00:58,  1.17s/it]
# ----
# ----
# counter 21
# good 1 ---original 1 --- 0
# processed vehicels 1
#  80%|████████  | 202/251 [02:58<00:56,  1.15s/it]
# ----
# ----
# counter 22
# good 1 ---original 1 --- 0
# processed vehicels 1
#  81%|████████  | 203/251 [02:59<00:55,  1.15s/it]
# ----
# ----
# counter 23
# good 1 ---original 1 --- 0
# processed vehicels 1
#  81%|████████▏ | 204/251 [03:00<00:55,  1.18s/it]
# ----
# ----
# counter 24
# good 1 ---original 1 --- 0
# processed vehicels 1
#  82%|████████▏ | 205/251 [03:02<00:52,  1.15s/it]
# ----
# ----
# counter 25
# good 1 ---original 1 --- 0
# processed vehicels 1
#  82%|████████▏ | 206/251 [03:03<00:50,  1.13s/it]
# ----
# ----
# counter 26
# good 1 ---original 1 --- 0
# processed vehicels 1
#  82%|████████▏ | 207/251 [03:04<00:50,  1.14s/it]
# ----
# ----
# counter 27
# good 1 ---original 1 --- 0
# processed vehicels 1
#  83%|████████▎ | 208/251 [03:05<00:48,  1.12s/it]
# ----
# ----
# counter 28
# good 1 ---original 1 --- 0
# processed vehicels 1
#  83%|████████▎ | 209/251 [03:06<00:45,  1.09s/it]
# ----
# ----
# counter 29
# good 1 ---original 1 --- 0
# processed vehicels 1
#  84%|████████▎ | 210/251 [03:07<00:45,  1.10s/it]
# ----
# ----
# counter 30
# good 1 ---original 1 --- 0
# processed vehicels 1
#  84%|████████▍ | 211/251 [03:08<00:44,  1.11s/it]
# ----
# ----
# counter 31
# good 1 ---original 1 --- 0
# processed vehicels 1
#  84%|████████▍ | 212/251 [03:09<00:45,  1.15s/it]
# ----
# ----
# counter 32
# good 1 ---original 1 --- 0
# processed vehicels 1
#  85%|████████▍ | 213/251 [03:11<00:44,  1.16s/it]
# ----
# ----
# counter 33
# good 1 ---original 1 --- 0
# processed vehicels 1
#  85%|████████▌ | 214/251 [03:12<00:42,  1.16s/it]
# ----
# ----
# counter 34
# good 1 ---original 1 --- 0
# processed vehicels 1
#  86%|████████▌ | 215/251 [03:13<00:40,  1.12s/it]
# ----
# ----
# counter 35
# good 1 ---original 1 --- 0
# processed vehicels 1
#  86%|████████▌ | 216/251 [03:14<00:39,  1.14s/it]
# ----
# ----
# counter 36
# good 1 ---original 1 --- 0
# processed vehicels 1
#  86%|████████▋ | 217/251 [03:15<00:40,  1.20s/it]
# ----
# ----
# counter 37
# good 1 ---original 1 --- 0
# processed vehicels 1
#  87%|████████▋ | 218/251 [03:16<00:39,  1.21s/it]
# ----
# counter 38
# good 1 ---original 1 --- 0
# processed vehicels 1
#  87%|████████▋ | 219/251 [03:18<00:37,  1.17s/it]
# ----
# counter 39
# good 1 ---original 1 --- 0
# processed vehicels 1
#  88%|████████▊ | 220/251 [03:19<00:35,  1.15s/it]
# ----
# counter 40
# good 1 ---original 1 --- 0
# processed vehicels 1
#  88%|████████▊ | 221/251 [03:20<00:33,  1.12s/it]
# ----
# counter 41
# good 1 ---original 1 --- 0
# processed vehicels 1
#  88%|████████▊ | 222/251 [03:21<00:33,  1.14s/it]
# ----
# counter 42
# good 1 ---original 1 --- 0
# processed vehicels 1
#  89%|████████▉ | 223/251 [03:22<00:32,  1.15s/it]
# ----
# counter 43
# good 1 ---original 1 --- 0
# processed vehicels 1
#  89%|████████▉ | 224/251 [03:23<00:30,  1.14s/it]
# ----
# counter 44
# good 1 ---original 1 --- 0
# processed vehicels 1
#  90%|████████▉ | 225/251 [03:24<00:28,  1.08s/it]
# ----
# counter 45
# good 1 ---original 1 --- 0
# processed vehicels 1
#  90%|█████████ | 226/251 [03:25<00:25,  1.03s/it]
# ----
# counter 46
# good 1 ---original 1 --- 0
# processed vehicels 1
#  90%|█████████ | 227/251 [03:26<00:24,  1.03s/it]
# ----
# counter 47
# good 1 ---original 1 --- 0
# processed vehicels 1
#  91%|█████████ | 228/251 [03:27<00:25,  1.12s/it]
# ----
# ----
# counter 48
# good 1 ---original 1 --- 0
# processed vehicels 1
#  91%|█████████ | 229/251 [03:29<00:25,  1.16s/it]
# ----
# ----
# counter 49
# good 1 ---original 1 --- 0
# processed vehicels 1
#  92%|█████████▏| 230/251 [03:30<00:24,  1.18s/it]
# ----
# counter 50
# good 1 ---original 1 --- 0
# processed vehicels 1
#  92%|█████████▏| 231/251 [03:31<00:23,  1.19s/it]
# ----
# counter 51
# good 1 ---original 1 --- 0
# processed vehicels 1
#  92%|█████████▏| 232/251 [03:32<00:22,  1.20s/it]
# ----
# counter 52
# good 1 ---original 1 --- 0
# processed vehicels 1
#  93%|█████████▎| 233/251 [03:34<00:22,  1.26s/it]
# ----
# counter 53
# good 1 ---original 1 --- 0
# processed vehicels 1
#  93%|█████████▎| 234/251 [03:35<00:21,  1.26s/it]
# ----
# counter 54
# good 1 ---original 1 --- 0
# processed vehicels 1
#  94%|█████████▎| 235/251 [03:36<00:18,  1.19s/it]
# ----
# counter 55
# good 1 ---original 1 --- 0
# processed vehicels 1
#  94%|█████████▍| 236/251 [03:37<00:16,  1.11s/it]
# ----
# counter 56
# good 1 ---original 1 --- 0
# processed vehicels 1
#  94%|█████████▍| 237/251 [03:38<00:14,  1.03s/it]
# ----
# counter 57
# good 1 ---original 1 --- 0
# processed vehicels 1
#  95%|█████████▍| 238/251 [03:39<00:12,  1.04it/s]
# ----
# counter 58
# good 1 ---original 1 --- 0
# processed vehicels 1
#  95%|█████████▌| 239/251 [03:39<00:11,  1.09it/s]
# ----
# counter 59
# good 1 ---original 1 --- 0
# processed vehicels 1
#  96%|█████████▌| 240/251 [03:40<00:09,  1.15it/s]
# ----
# counter 60
# good 1 ---original 1 --- 0
# processed vehicels 1
#  96%|█████████▌| 241/251 [03:41<00:08,  1.18it/s]
# ----
# counter 61
# good 1 ---original 1 --- 0
# processed vehicels 1
#  96%|█████████▋| 242/251 [03:42<00:07,  1.23it/s]
# ----
# counter 62
# good 1 ---original 1 --- 0
# processed vehicels 1
#  97%|█████████▋| 243/251 [03:42<00:06,  1.27it/s]
# ----
# counter 63
# good 1 ---original 1 --- 0
# processed vehicels 1
#  97%|█████████▋| 244/251 [03:43<00:05,  1.30it/s]
# ----
# counter 64
# good 1 ---original 1 --- 0
# processed vehicels 1
#  98%|█████████▊| 245/251 [03:44<00:04,  1.32it/s]
# ----
# counter 65
# good 1 ---original 1 --- 0
# processed vehicels 1
# ----
# ----
# ----
#  98%|█████████▊| 246/251 [03:45<00:03,  1.34it/s]
# counter 66
# good 2 ---original 2 --- 1
# processed vehicels 2
#  98%|█████████▊| 247/251 [03:45<00:02,  1.35it/s]
# ----
# counter 67
# good 1 ---original 2 --- 0
# processed vehicels 1
#  99%|█████████▉| 248/251 [03:46<00:02,  1.37it/s]
# ----
# good 2 ---original 2 --- 1
# processed vehicels 2
# ----
# ----
#  99%|█████████▉| 249/251 [03:47<00:01,  1.37it/s]
# counter 1
# counter 1
# good 1 ---original 2 --- 0
# processed vehicels 1
# ----
# ----
# ----
# 100%|█████████▉| 250/251 [03:47<00:00,  1.37it/s]
# counter 2
# good 2 ---original 2 --- 1
# processed vehicels 2
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: project_output.mp4
#
# CPU times: user 3min 30s, sys: 11 s, total: 3min 41s
# Wall time: 3min 49s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(video_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="project_output.mp4">
# </video>
